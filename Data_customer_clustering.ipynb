# %% [markdown]
# <a href="https://colab.research.google.com/github/ghamawell/Data-customer-clustering/blob/main/Data_customer_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# library

import pandas as pd
import datetime
import numpy as np
import joblib
import datetime as dt
from datetime import date
from datetime import datetime
from mpl_toolkits.mplot3d import Axes3D # 3d plot

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

from re import search
import re

import pickle
import warnings

plt.rcParams['figure.figsize'] = (20, 10)
sns.set_style('whitegrid')

# %%
#Set Confuguration

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 200)
pd.set_option('display.float_format', lambda x: '%.4f' % x)

sns.set(rc={'figure.figsize':(18,6)})

# %% [markdown]
# *Case*
#
# Every company must a have a product that will be sold to customers Using data set from Kaggle i'll build a machine learning model to clustering each customer and get the profile of customers, that will help for any department like CRM, Marketing etc to measure the performance and ensure target goes well.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/'My Drive'/'Colab Notebooks'/
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
ls

# %%
#read the dataset

df_raw = pd.read_excel('online_retail.xlsx')

# %%
df_raw.tail()
# Out:
#        InvoiceNo StockCode lower                      Description  Quantity  \
# 541904    581587     22613   NaN      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899   NaN     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254   NaN    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255   NaN  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138   NaN    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00     0.8500  12680.0000  France
# 541905 2011-12-09 12:50:00     2.1000  12680.0000  France
# 541906 2011-12-09 12:50:00     4.1500  12680.0000  France
# 541907 2011-12-09 12:50:00     4.1500  12680.0000  France
# 541908 2011-12-09 12:50:00     4.9500  12680.0000  France

# %% [markdown]
# *Data Wrangling*

# %%
df_raw.groupby('Country')['CustomerID'].nunique().head()
# Out:
# Country
# Australia     9
# Austria      11
# Bahrain       2
# Belgium      25
# Brazil        1
# Name: CustomerID, dtype: int64

# %%
df_raw['Amount'] = df_raw['Quantity'] * df_raw['UnitPrice']
df_raw.head()
# Out:
#   InvoiceNo StockCode                                lower  \
# 0    536365    85123A   white hanging heart t-light holder
# 1    536365     71053                  white metal lantern
# 2    536365    84406B       cream cupid hearts coat hanger
# 3    536365    84029G  knitted union flag hot water bottle
# 4    536365    84029E       red woolly hottie white heart.
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  Amount
# 0     2.5500  17850.0000  United Kingdom 15.3000
# 1     3.3900  17850.0000  United Kingdom 20.3400
# 2     2.7500  17850.0000  United Kingdom 22.0000
# 3     3.3900  17850.0000  United Kingdom 20.3400
# 4     3.3900  17850.0000  United Kingdom 20.3400

# %%
df_raw.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# lower          540093
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# Amount              0
# dtype: int64

# %%
# fill the null value in ID Customer to keep the information
df_raw['CustomerID'].fillna(df_raw['Country'].map(str)+ '-' + df_raw['Description'].map(str), inplace = True)

# %%
# Data Cleansing
df_raw1 = df_raw[['CustomerID','InvoiceNo','StockCode','Description','Quantity','InvoiceDate','UnitPrice','Country','Amount']]
df_clean = df_raw1.dropna()

# %% [markdown]
# Start for create clustering using K-means
#
# Pertama kita masukan data df_clean ke dalam df_kmeans dengan memperhatikan nilai variabel numeric yang akan diolah
#
# First, we will assgin df_clean to variable df_kmeans that we will use for data modeling

# %%
df_kmeans = df_clean[['CustomerID','InvoiceDate','Quantity','Amount']]
df_kmeans['InvoiceDate']= pd.to_datetime(df_kmeans['InvoiceDate']).dt.date

df_kmeans['InvoiceDate'] = df_kmeans['InvoiceDate'].astype('datetime64')
# Out:
# <ipython-input-14-0e239b5a1e2c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kmeans['InvoiceDate']= pd.to_datetime(df_kmeans['InvoiceDate']).dt.date
# <ipython-input-14-0e239b5a1e2c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kmeans['InvoiceDate'] = df_kmeans['InvoiceDate'].astype('datetime64')

# %% [markdown]
# Data PreProcessing

# %%
#create df_agg for doing aggregation using groupby
df_agg = df_kmeans.groupby('CustomerID').agg(
    Max_Transactions = pd.NamedAgg(column = 'Amount',aggfunc=max),
    Min_Transactions = pd.NamedAgg(column = 'Amount',aggfunc=min),
    Average_Transactions = pd.NamedAgg(column = 'Amount', aggfunc="mean"),
    Freq_Transactions = pd.NamedAgg(column = 'CustomerID', aggfunc=len),
    Max_Date = pd.NamedAgg(column = 'InvoiceDate',aggfunc=max),
    Min_Date = pd.NamedAgg(column = 'InvoiceDate',aggfunc=min),
    Amount = pd.NamedAgg(column = 'Amount',aggfunc=sum)
)

#create new column that name is age for given age of each of customer from first transactions and last transactions
df_agg['Recency'] = df_agg['Max_Date'] - df_agg['Min_Date']
df_agg['Recency'] = df_agg['Recency'].dt.days.astype('int16')


#using import datetime to convert the date of today
import datetime
def today_date():
    '''
    utils:
    get the datetime of today
    '''
    date=datetime.datetime.now().date()
    date=pd.to_datetime(date)
    return date
df_agg['Date'] = today_date()

#get column Age from delta Date colomn and Min_Date column
df_agg['Age'] = df_agg['Date'] - df_agg['Min_Date']
df_agg['Age'] = df_agg['Age'].dt.days.astype('int16')
df_agg
# Out:
#                                                Max_Transactions  \
# CustomerID
# 12346.0                                              77183.6000
# 12347.0                                                249.6000
# 12348.0                                                240.0000
# 12349.0                                                300.0000
# 12350.0                                                 40.0000
# ...                                                         ...
# Unspecified-WASH BAG VINTAGE ROSE PAISLEY                2.5500
# Unspecified-WOODEN BOX OF DOMINOES                      15.0000
# Unspecified-WOODEN HAPPY BIRTHDAY GARLAND               17.7000
# Unspecified-WOODEN UNION JACK BUNTING                    5.9500
# Unspecified-WORLD WAR 2 GLIDERS ASSTD DESIGNS           13.9200
#
#                                                Min_Transactions  \
# CustomerID
# 12346.0                                             -77183.6000
# 12347.0                                                  5.0400
# 12348.0                                                 13.2000
# 12349.0                                                  6.6400
# 12350.0                                                  8.5000
# ...                                                         ...
# Unspecified-WASH BAG VINTAGE ROSE PAISLEY                2.5500
# Unspecified-WOODEN BOX OF DOMINOES                       6.2500
# Unspecified-WOODEN HAPPY BIRTHDAY GARLAND                2.9500
# Unspecified-WOODEN UNION JACK BUNTING                    5.9500
# Unspecified-WORLD WAR 2 GLIDERS ASSTD DESIGNS           13.9200
#
#                                                Average_Transactions  \
# CustomerID
# 12346.0                                                      0.0000
# 12347.0                                                     23.6813
# 12348.0                                                     57.9755
# 12349.0                                                     24.0760
# 12350.0                                                     19.6706
# ...                                                             ...
# Unspecified-WASH BAG VINTAGE ROSE PAISLEY                    2.5500
# Unspecified-WOODEN BOX OF DOMINOES                          10.0000
# Unspecified-WOODEN HAPPY BIRTHDAY GARLAND                   10.3250
# Unspecified-WOODEN UNION JACK BUNTING                        5.9500
# Unspecified-WORLD WAR 2 GLIDERS ASSTD DESIGNS               13.9200
#
#                                                Freq_Transactions   Max_Date  \
# CustomerID
# 12346.0                                                        2 2011-01-18
# 12347.0                                                      182 2011-12-07
# 12348.0                                                       31 2011-09-25
# 12349.0                                                       73 2011-11-21
# 12350.0                                                       17 2011-02-02
# ...                                                          ...        ...
# Unspecified-WASH BAG VINTAGE ROSE PAISLEY                      1 2011-07-08
# Unspecified-WOODEN BOX OF DOMINOES                             3 2011-11-24
# Unspecified-WOODEN HAPPY BIRTHDAY GARLAND                      2 2011-07-08
# Unspecified-WOODEN UNION JACK BUNTING                          1 2011-09-02
# Unspecified-WORLD WAR 2 GLIDERS ASSTD DESIGNS                  2 2011-09-02
#
#                                                 Min_Date    Amount  Recency  \
# CustomerID
# 12346.0                                       2011-01-18    0.0000        0
# 12347.0                                       2010-12-07 4310.0000      365
# 12348.0                                       2010-12-16 1797.2400      283
# 12349.0                                       2011-11-21 1757.5500        0
# 12350.0                                       2011-02-02  334.4000        0
# ...                                                  ...       ...      ...
# Unspecified-WASH BAG VINTAGE ROSE PAISLEY     2011-07-08    2.5500        0
# Unspecified-WOODEN BOX OF DOMINOES            2011-07-08   30.0000      139
# Unspecified-WOODEN HAPPY BIRTHDAY GARLAND     2011-05-19   20.6500       50
# Unspecified-WOODEN UNION JACK BUNTING         2011-09-02    5.9500        0
# Unspecified-WORLD WAR 2 GLIDERS ASSTD DESIGNS 2011-07-08   27.8400       56
#
#                                                     Date   Age
# CustomerID
# 12346.0                                       2023-08-15  4592
# 12347.0                                       2023-08-15  4634
# 12348.0                                       2023-08-15  4625
# 12349.0                                       2023-08-15  4285
# 12350.0                                       2023-08-15  4577
# ...                                                  ...   ...
# Unspecified-WASH BAG VINTAGE ROSE PAISLEY     2023-08-15  4421
# Unspecified-WOODEN BOX OF DOMINOES            2023-08-15  4421
# Unspecified-WOODEN HAPPY BIRTHDAY GARLAND     2023-08-15  4471
# Unspecified-WOODEN UNION JACK BUNTING         2023-08-15  4365
# Unspecified-WORLD WAR 2 GLIDERS ASSTD DESIGNS 2023-08-15  4421
#
# [8878 rows x 10 columns]

# %%
#Assign to df_ml where we have to select columns that we will use for modeling
df_ml = df_agg.iloc[:,[0,1,2,3,6,7,9]]

# %%
#Eksploratory Data Analysis

sns.distplot(df_ml['Average_Transactions'], bins = 30)
# Out:
# <ipython-input-17-baf911952b95>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_ml['Average_Transactions'], bins = 30)
# <Axes: xlabel='Average_Transactions', ylabel='Density'>

# %%
#Check the scatter plot to see corelation and anomali data

plt.figure(figsize=(10,6))
plt.scatter(df_ml['Freq_Transactions'],df_ml['Amount'], marker='o');
plt.xlabel('Freq_Transactions')
plt.ylabel('Amount')
plt.title('Scatter plot between Freq and Amount')
# Out:
# Text(0.5, 1.0, 'Scatter plot between Freq and Amount')

# %% [markdown]
# From the ghrapic and plot we saw for average transactions is belom from 0, and we will drop the data because it means like canceled order from customer

# %%
# exclude df_ml from Amount < 1
row_cut = df_ml['Amount'] <1
df_ml = df_ml[~row_cut]

# %% [markdown]
# Seperate the customer 'row_exclude' that have special value from amount and frequency of transactions, and we will labeling with Special Customer. and avoid data bias

# %%
#Exclude the row who have <= 0 Amount
plt.figure(figsize=(10,6))
plt.scatter(df_ml['Freq_Transactions'],df_ml['Amount'], marker='o');
plt.xlabel('Freq_Transactions')
plt.ylabel('Amount')
plt.title('Scatter plot between Freq and Amount')
# Out:
# Text(0.5, 1.0, 'Scatter plot between Freq and Amount')

# %%
# see the correlation between each variable, example 'Max_Transactions have negatively' correlated with 'Min_Transactions'

fig_dims = (7, 7)
fig, ax = plt.subplots(figsize=fig_dims)
sns.heatmap(df_ml.corr(), annot=True, cmap='viridis')
# Out:
# <Axes: >

# %%
# Standardizing the variables

scaler = StandardScaler().fit_transform(df_ml.values)
scaled_data = pd.DataFrame(scaler, index = df_ml.index, columns=df_ml.columns)
scaled_data.head()
# Out:
#             Max_Transactions  Min_Transactions  Average_Transactions  \
# CustomerID
# 12347.0               0.0737            0.0190                0.0306
# 12348.0               0.0686            0.0233                0.4831
# 12349.0               0.1004            0.0198                0.0358
# 12350.0              -0.0374            0.0208               -0.0223
# 12352.0               0.1410           -0.1843               -0.0672
#
#             Freq_Transactions  Amount  Recency     Age
# CustomerID
# 12347.0                0.6928  0.4962   1.3565  0.9710
# 12348.0               -0.1851  0.0994   0.7950  0.8970
# 12349.0                0.0591  0.0931  -1.1429 -1.8980
# 12350.0               -0.2665 -0.1316  -1.1429  0.5024
# 12352.0                0.1870  0.0596   0.6375  0.3874

# %%
#Building Cluster Model, but before it we will find most appropriate 'K' Use The Elbow Method

wcss=[]
for i in range(1, 9):
    kmeans = KMeans(n_clusters = i, init = 'k-means++',
                    max_iter = 300, n_init = 10, random_state = 42)
    kmeans.fit(scaled_data)
    wcss_iter=kmeans.inertia_
    wcss.append(wcss_iter)
# Plotting the results onto a line graph to help us observe 'The Elbow'
plt.figure(figsize=(10,5))
no_clusters=range(1,9)
plt.plot(no_clusters, wcss,marker = "o")
plt.title('The elbow method', fontweight="bold")
plt.xlabel('Number of clusters(K)')
plt.ylabel('within Clusters Sum of Squares(WCSS)')
# Out:
# Text(0, 0.5, 'within Clusters Sum of Squares(WCSS)')

# %%
#Implement Kmeans Model

kmeans = KMeans(5)
#fit the data
kmeans.fit(scaled_data)

#Create a new data frame with the predicted clusters

df_cluster = df_ml
# cluster = scaled_data.copy()
df_cluster['cluster_pred'] = kmeans.fit_predict(scaled_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
#Labeling cluster for each customers
df_cluster.head()
# Out:
#             Max_Transactions  Min_Transactions  Average_Transactions  \
# CustomerID
# 12347.0             249.6000            5.0400               23.6813
# 12348.0             240.0000           13.2000               57.9755
# 12349.0             300.0000            6.6400               24.0760
# 12350.0              40.0000            8.5000               19.6706
# 12352.0             376.5000         -376.5000               16.2675
#
#             Freq_Transactions    Amount  Recency   Age  cluster_pred
# CustomerID
# 12347.0                   182 4310.0000      365  4634             2
# 12348.0                    31 1797.2400      283  4625             2
# 12349.0                    73 1757.5500        0  4285             0
# 12350.0                    17  334.4000        0  4577             0
# 12352.0                    95 1545.4100      260  4563             2

# %%
#cluster profilling
df_cluster.groupby('cluster_pred').mean()
# Out:
#               Max_Transactions  Min_Transactions  Average_Transactions  \
# cluster_pred
# 0                      70.5352           -4.1004               22.2366
# 1                  168469.6000      -168469.6000                0.7250
# 2                     100.8263          -15.7578               16.8002
# 3                    2383.1785        -1102.7269              150.8694
# 4                    3301.2500          613.4500             2248.3507
#
#               Freq_Transactions      Amount  Recency       Age
# cluster_pred
# 0                       27.4673    413.0307  40.9925 4426.8129
# 1                        4.0000      2.9000 205.0000 4472.0000
# 2                       92.4408   1575.5654 300.7604 4610.6973
# 3                     2680.0000 124530.4154 342.5385 4613.5385
# 4                        5.1667   8278.0833  69.6667 4426.1667

# %%
plt.figure(figsize=(6,6))
plt.scatter(df_cluster['Amount'],df_cluster['Age'],c=df_cluster['cluster_pred'],cmap='rainbow')
plt.title("Clustering customers based on Amount and Age", fontsize=15,fontweight="bold")
plt.xlabel("Amount")
plt.ylabel("Age")
# Out:
# Text(0, 0.5, 'Age')

# %%
# Using 3D for see the cluster

fig = plt.figure(1)
plt.clf()
ax = Axes3D(fig,
            rect = [0, 0, .95, 1],
            elev = 48,
            azim = 134)

plt.cla()
ax.scatter(df_cluster['Freq_Transactions'], df_cluster['Age'], df_cluster['Amount'],
           c = df_cluster['cluster_pred'],
           s = 110,
           cmap = 'spring',
           alpha = 0.5,
           edgecolor = 'darkgrey')
ax.set_xlabel('Age',
              fontsize = 16)
ax.set_ylabel('Amount',
              fontsize = 16)
ax.set_zlabel('Freq_Transactions',
              fontsize = 16)

plt.xlim(0,10000)
plt.ylim(0,7000)

plt.savefig('3d_plot.png')
plt.show()
